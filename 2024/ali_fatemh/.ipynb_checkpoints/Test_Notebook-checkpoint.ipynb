# %%
import matplotlib.pyplot as plt
import numpy as np





plt.style.use('_mpl-gallery')

# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)
print(x)
# plota
c

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# In a age let's say 20 there is a range a person that is 20 could get 30_000$ another person which is 20
# could get 10_0000 but a person in 20 could get 100_000 so we cannot use plot chart for this type of data 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("nba.csv")

df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np




fig, ax = plt.subplots()



ages = df["Age"]
salaries = df["Salary"]

x_value = np.arange(0, x.max(), 5)
y_value = np.arange(0, y.max(), 1000_000)

print(x_value, y_value)


plt.yticks(y_value)
ax.b(x_value, y_value, linewidth=2.0)


#plt.show()
# Out:
# [ 0.  5. 10. 15. 20. 25. 30. 35.] [       0.  1000000.  2000000.  3000000.  4000000.  5000000.  6000000.
#   7000000.  8000000.  9000000. 10000000. 11000000. 12000000. 13000000.
#  14000000. 15000000. 16000000. 17000000. 18000000. 19000000. 20000000.
#  21000000. 22000000. 23000000. 24000000.]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 22
#      18 print(x_value, y_value)
#      21 plt.yticks(y_value)
# ---> 22 ax.scatter(x_value, y_value, linewidth=2.0)
#      25 #plt.show()
#
# File ~/.cache/pypoetry/virtualenvs/students-C-A9I0CT-py3.11/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('nba.csv')

# Extract Age and Salary columns
age = df['Age']
salary = df['Salary']

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(age, salary, color='blue', alpha=0.5)  # alpha parameter controls transparency
plt.title('Age vs. Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()
